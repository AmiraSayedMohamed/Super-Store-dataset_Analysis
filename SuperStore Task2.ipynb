# %% [markdown]
# # Task2 - Exploratory Data Analysis on dataset "SampleSuperstore"
#
# Using Explaratory Data Analysis to fgure out business problems from the given dataset

# %%
# !pip install plotly
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting plotly
#   Downloading plotly-5.22.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting tenacity>=6.2.0 (from plotly)
#   Downloading tenacity-8.4.2-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: packaging in /home/amira/.local/lib/python3.8/site-packages (from plotly) (24.1)
# Downloading plotly-5.22.0-py3-none-any.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 1.0 MB/s eta 0:00:00m eta 0:00:010:00:010m
# Downloading tenacity-8.4.2-py3-none-any.whl (28 kB)
# Installing collected packages: tenacity, plotly
# Successfully installed plotly-5.22.0 tenacity-8.4.2

# %% [markdown]
# # Step1 - Importing the standard ML libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import scipy.stats as stats

# %% [markdown]
# # Step2 - Importing the dataset

# %%
df = pd.read_csv("Sample - Superstore.csv", encoding='ISO-8859-1')

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3       33311   South  FUR-TA-10000577        Furniture       Tables
# 4       33311   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]

# %% [markdown]
# # Step 3 - Data Analysis

# %%
# Check the shape of the imported dataseet
df.shape
print(f"Dataset have {df.shape[0]} rows and {df.shape[1]} features")
# Out:
# Dataset have 9994 rows and 21 features

# %%
#  Displaying the features names

df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
# Displaying the statistical measure
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %% [markdown]
# # The max profit on a single sale is 8399.976

# %%
# Checks the information of dataset using info () which shows the null values counts feautures names and Data type of every feature
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
#  19  Discount       9994 non-null   float64
#  20  Profit         9994 non-null   float64
# dtypes: float64(3), int64(3), object(15)
# memory usage: 1.6+ MB

# %%
# For EDA we have to check for the null values in the dataset and if any of the feature has one
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
# To check the number of unique values for each features
df.nunique()
# Out:
# Row ID           9994
# Order ID         5009
# Order Date       1237
# Ship Date        1334
# Ship Mode           4
# Customer ID       793
# Customer Name     793
# Segment             3
# Country             1
# City              531
# State              49
# Postal Code       631
# Region              4
# Product ID       1862
# Category            3
# Sub-Category       17
# Product Name     1850
# Sales            5825
# Quantity           14
# Discount           12
# Profit           7287
# dtype: int64

# %% [markdown]
# # From here we can have the following interpretaions
# 1. Different Types of Shiping Modes are ( Standard, Second, Firs Class and Same Day)
# 2. Categories of the products are (office Supplies, Technology, and furniture)
# 3. Segment of the customers are (Consumer, Home Office, Corporate)
# 4. Products are delivered in 49 states.
# 5. Region of serviced is (East , West, South, and Central)
# 6. There are several Sub-Categories of products
#
# # Step 4 - Data visualisation using Correlation Matric

# %%
# Computing the correlation matrix

# Select only the numeric columns
numeric_df = df.select_dtypes(include=[float, int])

# Compute the correlation matrix
correlation = numeric_df.corr()

correlation
# Out:
#                Row ID  Postal Code     Sales  Quantity  Discount    Profit
# Row ID       1.000000     0.009671 -0.001359 -0.004016  0.013480  0.012497
# Postal Code  0.009671     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales       -0.001359    -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity    -0.004016     0.012761  0.200795  1.000000  0.008623  0.066253
# Discount     0.013480     0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit       0.012497    -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
# Plotting a heat map using correlation matrix
plt.figure(figsize=(12,9))
sns.heatmap(correlation, annot=True)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# # Here we can observe that there is a positive correlation between Profit and sales increases profit increase

# %%
# We check the outliers of every feature using boxplot
plt.figure(figsize=(15,7))
sns.boxplot(data=df)
# Out:
# <Axes: >

# %% [markdown]
# # There are no outliers present as such

# %%
df['Category'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Category'>

# %%
# To from a graph showing different categories under each segment
pd.crosstab(df['Segment'],df['Category']).plot(kind="bar",stacked=True)
# Out:
# <Axes: xlabel='Segment'>

# %%
sns.displot(df["Sales"])

# %% [markdown]
# # It can be observed that the data here is highly right skewed

# %%
sns.pairplot(df)

# %% [markdown]
# 1. From the profit vs sales graph from above we can infer it is not necessary true that with the increase in sale profit increases
#
# 2. From the profit vs discount graph above we infer that when the discoun is till 0.3, there is a profit But if the discount increases beyond 0.3 there is a loss happening
#
# 3. From the discount vs sales graph from above we can infer that after a point when discount is increasing the total sales amount is decreasing

# %%
df['Sub-Category'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Sub-Category'>

# %% [markdown]
# # The SUB-CATEGORY is ARRANDED ON THE BASIS OF MOSFET SELLING PRODUCTS

# %%
pd.crosstab(df["Region"], df["Category"], df["Profit"], aggfunc="sum").plot(kind="bar", stacked=True)
# Out:
# <Axes: xlabel='Region'>

# %% [markdown]
# ## There is more profit from East and West regions

# %%
pd.crosstab(index=df["Category"],columns=df["Segment"], values=df["Profit"], aggfunc="sum").plot(kind="bar", stacked=True)
# Out:
# <Axes: xlabel='Category'>

# %% [markdown]
# ## although office supplies is the most selling category but the profit is the highest from the technology sector Under Technology the purchasing is the profit has come more from the Consmers segment

# %%
pd.crosstab(index=df["Category"], columns=df["Ship Mode"], values=df["Profit"], aggfunc="sum").plot(kind="bar", stacked=True)
# Out:
# <Axes: xlabel='Category'>

# %% [markdown]
#  ### The profit is high when the ship mode is "Standard Class" and the profit is negligible when the ship MOde is "same day"

# %%
plt.figure(figsize=(15,9))
sns.countplot(x=df['Sub-Category'])
print(df['Sub-Category'].value_counts())
# Out:
# Sub-Category
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: count, dtype: int64

# %% [markdown]
# ## Highes sold sub category is Binders and lowes sold sub category is Copiers

# %%
sns.lmplot(x="Profit", y="Sales", data=df, fit_reg=False, col="Category")
plt.show()

# %% [markdown]
# ## The profit is very low almost 0 in the furniture sector also the profit is high in the Technology sector

# %%
plt.figure(figsize=(15,8))
sns.countplot(x='Sub-Category', hue='Region', data=df)
print(df['Profit'].value_counts())
# Out:
# Profit
# 0.0000     65
# 6.2208     43
# 9.3312     38
# 5.4432     32
# 3.6288     32
#            ..
# 83.2508     1
# 16.1096     1
# 7.1988      1
# 1.6510      1
# 72.9480     1
# Name: count, Length: 7287, dtype: int64

# %%
plt.figure(figsize=(15,8))
sns.countplot(x='Sub-Category', hue='Segment', data=df)
# Out:
# <Axes: xlabel='Sub-Category', ylabel='count'>

# %%
# Forming a combined barplot for all the sub categories with respect to profit

fix, axs = plt.subplots(1, 1, figsize=(18, 5))
sns.barplot(x="Sub-Category", y="Profit", data=df, ax=axs)  # Pass data as DataFrame
# Out:
# <Axes: xlabel='Sub-Category', ylabel='Profit'>

# %% [markdown]
# ### Here we observe the profit of the losses with respect ot each of the sub categories
#
# we observe that Table, Bookcases and Fasteneers are in loss wheres the Coplers sub category has the highes amount of profit

# %%
fig=px.sunburst(df,path=['Country','Category','Sub-Category'],values='Sales',color='Category',hover_data=['Sales','Quantity','Profit'])
fig.update_layout(height=800)
fig.show()
# Out:
# <div>                            <div id="ec1998a8-ad3d-41ad-8215-2f7997e51d6c" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ec1998a8-ad3d-41ad-8215-2f7997e51d6c")) {                    Plotly.newPlot(                        "ec1998a8-ad3d-41ad-8215-2f7997e51d6c",                        [{"branchvalues":"total","customdata":[[167380.318,"(?)","(?)","Technology"],[328449.103,"(?)","(?)","Furniture"],[203412.733,"(?)","(?)","Office Supplies"],[12486.312,"(?)","(?)","Office Supplies"],[107532.16100000001,"(?)","(?)","Office Supplies"],[114879.9963,"(?)","(?)","Furniture"],[719047.032,"(?)","(?)","Office Supplies"],[741999.7953,"(?)","(?)","Furniture"],[206965.532,"(?)","(?)","Furniture"],[46673.538,"(?)","(?)","Office Supplies"],[223843.608,"(?)","(?)","Office Supplies"],[330007.054,"(?)","(?)","Technology"],[78479.206,"(?)","(?)","Office Supplies"],[91705.164,"(?)","(?)","Furniture"],[3024.28,"(?)","(?)","Office Supplies"],[149528.03,"(?)","(?)","Technology"],[27118.792,"(?)","(?)","Office Supplies"],[2297200.8603,"(?)","(?)","(?)"],[189238.631,"(?)","(?)","Technology"],[836154.033,"(?)","(?)","Technology"],[16476.402,"(?)","(?)","Office Supplies"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003eSales=%{customdata[0]}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cbr\u003eQuantity=%{customdata[1]}\u003cbr\u003eProfit=%{customdata[2]}\u003cbr\u003eCategory=%{customdata[3]}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["United States\u002fTechnology\u002fAccessories","United States\u002fFurniture\u002fChairs","United States\u002fOffice Supplies\u002fBinders","United States\u002fOffice Supplies\u002fLabels","United States\u002fOffice Supplies\u002fAppliances","United States\u002fFurniture\u002fBookcases","United States\u002fOffice Supplies","United States\u002fFurniture","United States\u002fFurniture\u002fTables","United States\u002fOffice Supplies\u002fSupplies","United States\u002fOffice Supplies\u002fStorage","United States\u002fTechnology\u002fPhones","United States\u002fOffice Supplies\u002fPaper","United States\u002fFurniture\u002fFurnishings","United States\u002fOffice Supplies\u002fFasteners","United States\u002fTechnology\u002fCopiers","United States\u002fOffice Supplies\u002fArt","United States","United States\u002fTechnology\u002fMachines","United States\u002fTechnology","United States\u002fOffice Supplies\u002fEnvelopes"],"labels":["Accessories","Chairs","Binders","Labels","Appliances","Bookcases","Office Supplies","Furniture","Tables","Supplies","Storage","Phones","Paper","Furnishings","Fasteners","Copiers","Art","United States","Machines","Technology","Envelopes"],"marker":{"colors":["#636efa","#EF553B","#00cc96","#00cc96","#00cc96","#EF553B","#00cc96","#EF553B","#EF553B","#00cc96","#00cc96","#636efa","#00cc96","#EF553B","#00cc96","#636efa","#00cc96","#ab63fa","#636efa","#636efa","#00cc96"]},"name":"","parents":["United States\u002fTechnology","United States\u002fFurniture","United States\u002fOffice Supplies","United States\u002fOffice Supplies","United States\u002fOffice Supplies","United States\u002fFurniture","United States","United States","United States\u002fFurniture","United States\u002fOffice Supplies","United States\u002fOffice Supplies","United States\u002fTechnology","United States\u002fOffice Supplies","United States\u002fFurniture","United States\u002fOffice Supplies","United States\u002fTechnology","United States\u002fOffice Supplies","","United States\u002fTechnology","United States","United States\u002fOffice Supplies"],"values":[167380.318,328449.103,203412.733,12486.312,107532.16100000001,114879.9963,719047.032,741999.7953,206965.532,46673.538,223843.608,330007.054,78479.206,91705.164,3024.28,149528.03,27118.792, ...

# %% [markdown]
# # THE FINAL INSIGHTS
#
# 1. When the discount is till 0.3 there is a profit.But if the discount increases beyond 0.3 there a loss will be incurred
# 2.Although office supplies is the most selling category but the profit is highest from the technology sector. Under which the the profit has come more from the Consumers segment.
# 3.Although Copiers is the least selling sub-category but has given the most profit out of all the sub-categories.
# 4.There is a huge loss from the furniture section.
# 5.The profit is high when the ship mode is "Standard Class" and the Profit is negligible when the ship Mode is "Same day"
# 6.The profit is more from the east and west region of the country.
# SUGGESTIONS TO THE BUSSINESS
# 1.THE DISCOUNT SHOULD NOT BE INCREASED BEYOND 0.3.
# 2.THE FURNITURE CATEGORY IS CAUSING A LOT OF LOSS, SO THE COMPANY CAN STOP SELLING FURNITURES OR SHOULD INCREASE THE PRICE OF THE FURNITURE CATEGORY OR CAN TRY TO REDUCE THE OVERALL COST OF THE PRODUCT
# 3.IF THE SHIPPING MODE IS "SAME DAY", THE SHIPPING CHARGES SHOULD BE INCREASED.
# 4.THE COMPANY SHOULD FOCUS MORE ON THE TECHNOLOGY SECTION
